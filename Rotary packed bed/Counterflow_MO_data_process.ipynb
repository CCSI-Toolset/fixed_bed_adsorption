# %% [markdown]
# # Identifiability analysis
#
# This notebook does two parts of analysis:
#
# 1) Compute first-order sensitivity (Jacobian matrix)
#
# 2) Analyze sensitivities for identifiability.

# %%
import pickle 
import matplotlib.pyplot as plt
import numpy as np

# %%
def load_pickle(name): 
    file = open(name, "rb")
    data = pickle.load(file)
    file.close()
    return data

# %%
parameter = {
    "C1": 2.562434e-12, 
    "hgx": 25 * 1e-3, 
    "delH_1": 98.76,
    "delH_2": 77.11, 
    "delH_3": 21.25
}

n_para =len(parameter)

step = 0.001

# %%
## Get measurement names 
# from here, we reorganize the measurements order 
#measure_keys = ["y_CO2", "C_CO2", "C_N2",
#               "Tg", "P", "vg", 
#               "q_CO2", "Ts"]

measure_keys = ["y_CO2", "P", "vg", "Tg", "Ts"]
parameter_names = [
    "C1",
    "hgx",
    "delH_1",
    "delH_2",
    "delH_3"
]

# all measurement order 
# Tg [0.01, 0.01], ...,
# Pg, 

#store_option = "20*20" # full grid 
store_option = "10*10" # half grid 

if store_option == "20*20":
    z_pos = [0.01, 0.016, 0.027, 0.043, 0.071, 0.115, 0.188, 
                  0.307, 0.403, 0.5, 0.597, 0.693, 0.812, 0.885, 
                  0.929, 0.957, 0.973, 0.984, 0.99, 1.0] 

    theta_pos = [0.005, 0.008, 0.012, 0.018, 0.028, 
                      0.042, 0.065, 0.1, 0.15, 
                      0.199, 0.299, 0.349, 0.398, 0.498, 0.597, 
                      0.697, 0.796, 0.896, 0.995, 1.0]
    
elif store_option == "10*10":
    z_pos_ads = [0.115, 0.188, 0.307, 0.403,0.5, 0.597, 0.693, 0.812, 0.885, 1.0]
    z_pos_des = [0, 0.115, 0.188, 0.307, 0.403,0.5, 0.597, 0.693, 0.812, 0.885]
    
    theta_pos =  [0.1, 0.199, 0.299, 0.349, 0.398, 0.498, 0.597, 0.697, 0.796, 0.896]
    
elif store_option == "5*5": 
    z_pos = [0.01, 0.307, 0.5, 0.812, 1.0]
    
    theta_pos = [0.005, 0.01, 0.498, 0.796, 1.0]
    
elif store_option == "3*3":
    
    z_pos = [0.01, 0.5, 1.0]
    theta_pos = [0.005, 0.01, 1.0]

n_total_measurements = len(z_pos_ads)*len(theta_pos)

# %% [markdown]
# ## Compute Jacobian with finite difference scheme

# %%
# For five parameters, run both its upper and lower perturbation 
# Stored ads. and des. results separately
'''
upper_ads_c1 = load_pickle("./sensitivity_solution/C1_upper_ads_round")
upper_des_c1 = load_pickle("./sensitivity_solution/C1_upper_des_round")
lower_ads_c1 = load_pickle("./sensitivity_solution/C1_lower_ads_round")
lower_des_c1 = load_pickle("./sensitivity_solution/C1_lower_des_round")

lower_ads_hgx = load_pickle("./sensitivity_solution/hgx_lower_ads_round")
lower_des_hgx = load_pickle("./sensitivity_solution/hgx_lower_des_round")

lower_ads_h1 = load_pickle("./sensitivity_solution/h1_lower_ads_round")
lower_des_h1 = load_pickle("./sensitivity_solution/h1_lower_des_round")

upper_ads_h2 = load_pickle("./sensitivity_solution/h2_upper_ads_round")
upper_des_h2 = load_pickle("./sensitivity_solution/h2_upper_des_round")
lower_ads_h2 = load_pickle("./sensitivity_solution/h2_lower_ads_round")
lower_des_h2 = load_pickle("./sensitivity_solution/h2_lower_des_round")

upper_ads_h3 = load_pickle("./sensitivity_solution/h3_upper_ads_round")
upper_des_h3 = load_pickle("./sensitivity_solution/h3_upper_des_round")
lower_ads_h3 = load_pickle("./sensitivity_solution/h3_lower_ads_round")
lower_des_h3 = load_pickle("./sensitivity_solution/h3_lower_des_round")
'''
# Out:
# '\nupper_ads_c1 = load_pickle("./sensitivity_solution/C1_upper_ads_round")\nupper_des_c1 = load_pickle("./sensitivity_solution/C1_upper_des_round")\nlower_ads_c1 = load_pickle("./sensitivity_solution/C1_lower_ads_round")\nlower_des_c1 = load_pickle("./sensitivity_solution/C1_lower_des_round")\n\nlower_ads_hgx = load_pickle("./sensitivity_solution/hgx_lower_ads_round")\nlower_des_hgx = load_pickle("./sensitivity_solution/hgx_lower_des_round")\n\nlower_ads_h1 = load_pickle("./sensitivity_solution/h1_lower_ads_round")\nlower_des_h1 = load_pickle("./sensitivity_solution/h1_lower_des_round")\n\nupper_ads_h2 = load_pickle("./sensitivity_solution/h2_upper_ads_round")\nupper_des_h2 = load_pickle("./sensitivity_solution/h2_upper_des_round")\nlower_ads_h2 = load_pickle("./sensitivity_solution/h2_lower_ads_round")\nlower_des_h2 = load_pickle("./sensitivity_solution/h2_lower_des_round")\n\nupper_ads_h3 = load_pickle("./sensitivity_solution/h3_upper_ads_round")\nupper_des_h3 = load_pickle("./sensitivity_solution/h3_upper_des_round")\nlower_ads_h3 = load_pickle("./sensitivity_solution/h3_lower_ads_round")\nlower_des_h3 = load_pickle("./sensitivity_solution/h3_lower_des_round")\n'

# %%
def convert_tuple(file):
    
    new_file = {}
    for a, b in file:
        
        v = file[(a,b)]
        if a not in [0,1.0]:
            a = round(a, 3)
        
        if b!= 0.1:
            b = round(b, 3)
        new_file[(a,b)] = v
    
    return new_file

# %%
# For five parameters, run both its upper and lower perturbation 
# Stored ads. and des. results separately
lower_ads_c1 = load_pickle("./MBDOE_sens_001/Tgin_des_393_001/Tgin_ads_363/Tgads363_Tgdes393_C1low_ads")
lower_des_c1 = load_pickle("./MBDOE_sens_001/Tgin_des_393_001/Tgin_ads_363/Tgads363_Tgdes393_C1low_des")

lower_ads_hgx = load_pickle("./MBDOE_sens_001/Tgin_des_393_001/Tgin_ads_363/Tgads363_Tgdes393_hgxlow_ads")
lower_des_hgx = load_pickle("./MBDOE_sens_001/Tgin_des_393_001/Tgin_ads_363/Tgads363_Tgdes393_hgxlow_des")

lower_ads_h1 = load_pickle("./MBDOE_sens_001/Tgin_des_393_001/Tgin_ads_363/Tgads363_Tgdes393_h1low_ads")
lower_des_h1 = load_pickle("./MBDOE_sens_001/Tgin_des_393_001/Tgin_ads_363/Tgads363_Tgdes393_h1low_des")

lower_ads_h2 = load_pickle("./MBDOE_sens_001/Tgin_des_393_001/Tgin_ads_363/Tgads363_Tgdes393_h2low_ads")
lower_des_h2 = load_pickle("./MBDOE_sens_001/Tgin_des_393_001/Tgin_ads_363/Tgads363_Tgdes393_h2low_des")

lower_ads_h3 = load_pickle("./MBDOE_sens_001/Tgin_des_393_001/Tgin_ads_363/Tgads363_Tgdes393_h3low_ads")
lower_des_h3 = load_pickle("./MBDOE_sens_001/Tgin_des_393_001/Tgin_ads_363/Tgads363_Tgdes393_h3low_des")

# %%
print("lower_des_c1:", lower_des_c1["Tg"][(0,0.697)])
print("lower_des_hgx:", lower_des_hgx["Tg"][(0,0.697)])
print("lower_des_h1:", lower_des_h1["Tg"][(0,0.697)])
print("lower_des_h2:", lower_des_h2["Tg"][(0,0.697)])
print("lower_des_h3:", lower_des_h3["Tg"][(0,0.697)])
print("base:", original_des["Tg"][(0,0.697)])


(417.6215982274166-417.6216386614257)/0.001
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print("lower_des_c1:", lower_des_c1["Tg"][(0,0.697)])
#       2 print("lower_des_hgx:", lower_des_hgx["Tg"][(0,0.697)])
#       3 print("lower_des_h1:", lower_des_h1["Tg"][(0,0.697)])
#
# KeyError: (0, 0.697)

# %%
# we also have original case with original parameter nominal values
original_ads = load_pickle("./MBDOE_sens_001/Tgin_des_393_001/Tgin_ads_363/Tgads363_Tgdes393_base_ads")
original_des = load_pickle("./MBDOE_sens_001/Tgin_des_393_001/Tgin_ads_363/Tgads363_Tgdes393_base_des")

# %%
def compare(key, z, o): 
    print(lower_des_c1[key][z,o])
    print(lower_des_hgx[key][(z,o)])
    print(lower_des_h1[key][(z,o)])
    print(lower_des_h2[key][(z,o)])
    print(lower_des_h3[key][(z,o)])

    print(original_des[key][(z,o)])
    
compare("Tg", 0.885, 0.349) # des_7_9
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 10
#       6     print(lower_des_h3[key][(z,o)])
#       8     print(original_des[key][(z,o)])
# ---> 10 compare("Tg", 0.885, 0.349) # des_7_9
#
# Cell In[8], line 2, in compare(key, z, o)
#       1 def compare(key, z, o):
# ----> 2     print(lower_des_c1[key][z,o])
#       3     print(lower_des_hgx[key][(z,o)])
#       4     print(lower_des_h1[key][(z,o)])
#
# KeyError: (0.885, 0.349)

# %%
def gradient(upper, lower, original, step, param_value, 
             option="scale_parameter", 
             finite_diff_option="central"):
    if finite_diff_option=="central":
        if option=="scale_parameter":
            return (upper-lower)/2/step
        elif option=="not_scale_parameter":
            return (upper-lower)/2/step/param_value
        elif option=="scale_para_and_measure":
            return (upper/original-lower/original)/2/step
    elif finite_diff_option=="upper":
        if option=="scale_parameter":
            return (upper-original)/step
        elif option=="not_scale_parameter":
            return (upper-original)/step/param_value
        elif option=="scale_para_and_measure":
            return (upper/original-1)/step
    elif finite_diff_option=="lower":
        if option=="scale_parameter":
            return (original-lower)/step
        elif option=="not_scale_parameter":
            return (original-lower)/step/param_value
        elif option=="scale_para_and_measure":
            return (original-lower)/step
    else:
        raise ValueError("Finite_diff_option should be upper, lower, or central")

# %%
def jacobian_and_var(key, ads_measure=True, 
                     scale_option="scale_parameter", 
                     step=0.001, std=0.01):
    """
    Compute Jacobian and variance of one measurement
    
    Arguments 
    ---------
    key: measurement name 
    ads_measure: if this is this measurement in the adsorption part 
    scale_option:  
    step: 0.001 is default 
    std: standard deviation, 0.01 is the default 
    
    Return 
    ------
    jacobian: numpy array of shape [Nm*Np], Np = 5, Nm =  
    var: numpy array of shape [Nm],
    """
    # adsorption section measurements 
    #ads_upper_key_c1 = upper_ads_c1[key]
    ads_lower_key_c1 = convert_tuple(lower_ads_c1[key])

    #ads_upper_key_hgx = upper_ads_hgx[key]
    ads_lower_key_hgx = convert_tuple(lower_ads_hgx[key])

    #ads_upper_key_h1 = upper_ads_h1[key]
    ads_lower_key_h1 = convert_tuple(lower_ads_h1[key])

    #ads_upper_key_h2 = upper_ads_h2[key]
    ads_lower_key_h2 = convert_tuple(lower_ads_h2[key])

    #ads_upper_key_h3 = upper_ads_h3[key]
    ads_lower_key_h3 = convert_tuple(lower_ads_h3[key])

    ads_original = convert_tuple(original_ads[key])

    # desorption section measurements
    #des_upper_key_c1 = upper_des_c1[key]
    des_lower_key_c1 = convert_tuple(lower_des_c1[key])

    #des_upper_key_hgx = upper_des_hgx[key]
    des_lower_key_hgx = convert_tuple(lower_des_hgx[key])

    #des_upper_key_h1 = upper_ads_h1[key]
    des_lower_key_h1 = convert_tuple(lower_des_h1[key])

    #des_upper_key_h2 = upper_des_h2[key]
    des_lower_key_h2 = convert_tuple(lower_des_h2[key])

    #des_upper_key_h3 = upper_des_h3[key]
    des_lower_key_h3 = convert_tuple(lower_des_h3[key])

    des_original = convert_tuple(original_des[key])
    
    #print(ads_upper_key_c1)


    Q = np.zeros((2*n_total_measurements, n_para))
    
    #Q = [] # N*p, p is # of parameters, N is # of measurements  

    for z_idx in range(len(z_pos_ads)):
        for t_idx, j in enumerate(theta_pos):
            
            # first fill in adsorption gradients
            row_idx = z_idx*len(theta_pos) + t_idx 
            
            
            # adsorption 
            i = z_pos_ads[z_idx]
            
            print(row_idx, i, j)
            # C1 
            Q[row_idx][0] = gradient(ads_lower_key_c1[(i,j)], 
                                          ads_lower_key_c1[(i,j)], 
                                         ads_original[(i,j)], 
                                         step, 
                                         parameter["C1"], 
                                         option=scale_option,
                                         finite_diff_option="lower")
            
            # hgx
            Q[row_idx][1] = gradient(ads_lower_key_hgx[(i,j)], 
                                          ads_lower_key_hgx[(i,j)], 
                                         ads_original[(i,j)], 
                                         step, 
                                         parameter["hgx"], 
                                         option=scale_option,
                                         finite_diff_option="lower")
            
            # delH_1
            Q[row_idx][2] = gradient(ads_lower_key_h1[(i,j)], 
                                          ads_lower_key_h1[(i,j)], 
                                         ads_original[(i,j)], 
                                         0.0001, 
                                         parameter["delH_1"], 
                                         option=scale_option,
                                         finite_diff_option="lower")
            
            # delH_2
            Q[row_idx][3] = gradient(ads_lower_key_h2[(i,j)], 
                                          ads_lower_key_h2[(i,j)], 
                                         ads_original[(i,j)], 
                                         step, 
                                         parameter["delH_2"], 
                                         option=scale_option,
                                         finite_diff_option="lower")
            
            # delH_3
            Q[row_idx][4] = gradient(ads_lower_key_h3[(i,j)], 
                                          ads_lower_key_h3[(i,j)], 
                                         ads_original[(i,j)], 
                                         step, 
                                         parameter["delH_3"], 
                                         option=scale_option,
                                         finite_diff_option="lower")
                          
                                 
            # then fill in adsorption gradients
            row_idx_des = n_total_measurements + row_idx
            
            # desorption 
            i = z_pos_des[z_idx]
            #print(i)
            print(row_idx_des, i, j)
            # C1 
            Q[row_idx_des][0] = gradient(des_lower_key_c1[(i,j)], 
                                          des_lower_key_c1[(i,j)], 
                                         des_original[(i,j)], 
                                         step, 
                                         parameter["C1"], 
                                         option=scale_option,
                                         finite_diff_option="lower")
            
            # hgx
            Q[row_idx_des][1] = gradient(des_lower_key_hgx[(i,j)], 
                                        des_lower_key_hgx[(i,j)], 
                                         des_original[(i,j)], 
                                         step, 
                                         parameter["hgx"], 
                                         option=scale_option,
                                        finite_diff_option="lower")
            
            # delH_1
            Q[row_idx_des][2] = gradient(des_lower_key_h1[(i,j)], 
                                          des_lower_key_h1[(i,j)], 
                                         des_original[(i,j)], 
                                         0.0001, 
                                         parameter["delH_1"], 
                                         option=scale_option,
                                        finite_diff_option="lower")
            
            # delH_2
            Q[row_idx_des][3] = gradient(des_lower_key_h2[(i,j)], 
                                          des_lower_key_h2[(i,j)], 
                                         des_original[(i,j)], 
                                         step, 
                                         parameter["delH_2"], 
                                         option=scale_option,
                                         finite_diff_option="lower")
            
            # delH_3
            Q[row_idx_des][4] = gradient(des_lower_key_h3[(i,j)], 
                                          des_lower_key_h3[(i,j)], 
                                         des_original[(i,j)], 
                                         step, 
                                         parameter["delH_3"], 
                                         option=scale_option,
                                         finite_diff_option="lower")
    

    variance = np.zeros((2*n_total_measurements))
    
    if key == "Tg" or key=="Ts":
        var = 1**2
        
    elif key=="P":
        var = 0.005**2
        
    elif key=="y_CO2":
        var = 0.01**2
        
    elif key=="vg":
        var = 0.01**2
        
    for i in range(2*n_total_measurements):
        variance[i] = var
    
    '''
    for z_idx in range(len(z_pos_ads)):
        for t_idx, j in enumerate(theta_pos):
            
            # adsorption variance
            row_idx = z_idx*len(theta_pos) + t_idx
            
            i = z_pos_ads[z_idx]
            
            if scale_option=="scale_para_and_measure":
                variance[row_idx] = std*std
            else:
                variance[row_idx] = ads_original[(i,j)]**2*std*std
            
            
            # desorption variance 
            row_idx_des = row_idx + n_total_measurements
            
            i = z_pos_des[z_idx]
            
            if scale_option=="scale_para_and_measure":
                variance[row_idx_des] = std*std
            else:
                variance[row_idx_des] = des_original[(i,j)]**2*std*std
    '''
    return Q, variance

# %%
ans_Q, ans_var = jacobian_and_var("P", 
                        scale_option="scale_parameter", 
                        step=0.001)

print(np.shape(ans_Q))
print(len(ans_var))
print(ans_var)

# expect: 800*5, 
# ads: (z0, t0), ..., (z0, t19)
# ads: (z1, t0), ..., (z1, t19)
# ...
# des: (z0, t0), ..., (z0, t19)
# ... 
# des: (z19, t0), ..., (z19, t19)
# Out:
# 0 0.115 0.1
# 100 0 0.1
# 1 0.115 0.199
# 101 0 0.199
# 2 0.115 0.299
# 102 0 0.299
# 3 0.115 0.349
# 103 0 0.349
# 4 0.115 0.398
# 104 0 0.398
# 5 0.115 0.498
# 105 0 0.498
# 6 0.115 0.597
# 106 0 0.597
# 7 0.115 0.697
# 107 0 0.697
# 8 0.115 0.796
# 108 0 0.796
# 9 0.115 0.896
# 109 0 0.896
# 10 0.188 0.1
# 110 0.115 0.1
# 11 0.188 0.199
# 111 0.115 0.199
# 12 0.188 0.299
# 112 0.115 0.299
# 13 0.188 0.349
# 113 0.115 0.349
# 14 0.188 0.398
# 114 0.115 0.398
# 15 0.188 0.498
# 115 0.115 0.498
# 16 0.188 0.597
# 116 0.115 0.597
# 17 0.188 0.697
# 117 0.115 0.697
# 18 0.188 0.796
# 118 0.115 0.796
# 19 0.188 0.896
# 119 0.115 0.896
# 20 0.307 0.1
# 120 0.188 0.1
# 21 0.307 0.199
# 121 0.188 0.199
# 22 0.307 0.299
# 122 0.188 0.299
# 23 0.307 0.349
# 123 0.188 0.349
# 24 0.307 0.398
# 124 0.188 0.398
# 25 0.307 0.498
# 125 0.188 0.498
# 26 0.307 0.597
# 126 0.188 0.597
# 27 0.307 0.697
# 127 0.188 0.697
# 28 0.307 0.796
# 128 0.188 0.796
# 29 0.307 0.896
# 129 0.188 0.896
# 30 0.403 0.1
# 130 0.307 0.1
# 31 0.403 0.199
# 131 0.307 0.199
# 32 0.403 0.299
# 132 0.307 0.299
# 33 0.403 0.349
# 133 0.307 0.349
# 34 0.403 0.398
# 134 0.307 0.398
# 35 0.403 0.498
# 135 0.307 0.498
# 36 0.403 0.597
# 136 0.307 0.597
# 37 0.403 0.697
# 137 0.307 0.697
# 38 0.403 0.796
# 138 0.307 0.796
# 39 0.403 0.896
# 139 0.307 0.896
# 40 0.5 0.1
# 140 0.403 0.1
# 41 0.5 0.199
# 141 0.403 0.199
# 42 0.5 0.299
# 142 0.403 0.299
# 43 0.5 0.349
# 143 0.403 0.349
# 44 0.5 0.398
# 144 0.403 0.398
# 45 0.5 0.498
# 145 0.403 0.498
# 46 0.5 0.597
# 146 0.403 0.597
# 47 0.5 0.697
# 147 0.403 0.697
# 48 0.5 0.796
# 148 0.403 0.796
# 49 0.5 0.896
# 149 0.403 0.896
# 50 0.597 0.1
# 150 0.5 0.1
# 51 0.597 0.199
# 151 0.5 0.199
# 52 0.597 0.299
# 152 0.5 0.299
# 53 0.597 0.349
# 153 0.5 0.349
# 54 0.597 0.398
# 154 0.5 0.398
# 55 0.597 0.498
# 155 0.5 0.498
# 56 0.597 0.597
# 156 0.5 0.597
# 57 0.597 0.697
# 157 0.5 0.697
# 58 0.597 0.796
# 158 0.5 0.796
# 59 0.597 0.896
# 159 0.5 0.896
# 60 0.693 0.1
# 160 0.597 0.1
# 61 0.693 0.199
# 161 0.597 0.199
# 62 0.693 0.299
# 162 0.597 0.299
# 63 0.693 0.349
# 163 0.597 0.349
# 64 0.693 0.398
# 164 0.597 0.398
# 65 0.693 0.498
# 165 0.597 0.498
# 66 0.693 0.597
# 166 0.597 0.597
# 67 0.693 0.697
# 167 0.597 0.697
# 68 0.693 0.796
# 168 0.597 0.796
# 69 0.693 0.896
# 169 0.597 0.896
# 70 0.812 0.1
# 170 0.693 0.1
# 71 0.812 0.199
# 171 0.693 0.199
# 72 0.812 0.299
# 172 0.693 0.299
# 73 0.812 0.349
# 173 0.693 0.349
# 74 0.812 0.398
# 174 0.693 0.398
# 75 0.812 0.498
# 175 0.693 0.498
# 76 0.812 0.597
# 176 0.693 0.597
# 77 0.812 0.697
# 177 0.693 0.697
# 78 0.812 0.796
# 178 0.693 0.796
# 79 0.812 0.896
# 179 0.693 0.896
# 80 0.885 0.1
# 180 0.812 0.1
# 81 0.885 0.199
# 181 0.812 0.199
# 82 0.885 0.299
# 182 0.812 0.299
# 83 0.885 0.349
# 183 0.812 0.349
# 84 0.885 0.398
# 184 0.812 0.398
# 85 0.885 0.498
# 185 0.812 0.498
# 86 0.885 0.597
# 186 0.812 0.597
# 87 0.885 0.697
# 187 0.812 0.697
# 88 0.885 0.796
# 188 0.812 0.796
# 89 0.885 0.896
# 189 0.812 0.896
# 90 1.0 0.1
# 190 0.885 0.1
# 91 1.0 0.199
# 191 0.885 0.199
# 92 1.0 0.299
# 192 0.885 0.299
# 93 1.0 0.349
# 193 0.885 0.349
# 94 1.0 0.398
# 194 0.885 0.398
# 95 1.0 0.498
# 195 0.885 0.498
# 96 1.0 0.597
# 196 0.885 0.597
# 97 1.0 0.697
# 197 0.885 0.697
# 98 1.0 0.796
# 198 0.885 0.796
# 99 1.0 0.896
# 199 0.885 0.896
# (200, 5)
# 200
# [2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05 2.5e-05
#  2.5e-05 2.5e-05]

# %%
print(ans_var[0:10])
print(ans_var[70:80])
print(ans_var[80:90])
print(ans_var[90:100])
print(ans_var[100:110])
print(ans_var[110:120])
print(ans_var[190:200])

# %% [markdown]
# ## Save

# %%
def save_jaco_var(jacobian, variance, store_name=None, path=None, scale_option="scale_parameter"):
    """
    Store jacobian and variance data 
    """
    file = open(path+store_name+"_"+scale_option, "wb")
    pickle.dump(jacobian, file)
    file.close()

    file = open(path+ "Var_"+store_name+"_"+scale_option, "wb")
    pickle.dump(variance, file)
    file.close()

# %%
scale_opt = "scale_parameter"

if store_option == "20*20":
    store_path = "./jaco_and_var/"
elif store_option == "10*10":
    store_path = "./jaco_and_var_10t10/"


for n in measure_keys:
    ans_Q, ans_var = jacobian_and_var(n, 
                        scale_option=scale_opt, 
                        step=0.001)
    save_jaco_var(ans_Q, ans_var, store_name=n, path=store_path, scale_option=scale_opt)
# Out:
# 0 0.115 0.1
# 100 0 0.1
# 1 0.115 0.199
# 101 0 0.199
# 2 0.115 0.299
# 102 0 0.299
# 3 0.115 0.349
# 103 0 0.349
# 4 0.115 0.398
# 104 0 0.398
# 5 0.115 0.498
# 105 0 0.498
# 6 0.115 0.597
# 106 0 0.597
# 7 0.115 0.697
# 107 0 0.697
# 8 0.115 0.796
# 108 0 0.796
# 9 0.115 0.896
# 109 0 0.896
# 10 0.188 0.1
# 110 0.115 0.1
# 11 0.188 0.199
# 111 0.115 0.199
# 12 0.188 0.299
# 112 0.115 0.299
# 13 0.188 0.349
# 113 0.115 0.349
# 14 0.188 0.398
# 114 0.115 0.398
# 15 0.188 0.498
# 115 0.115 0.498
# 16 0.188 0.597
# 116 0.115 0.597
# 17 0.188 0.697
# 117 0.115 0.697
# 18 0.188 0.796
# 118 0.115 0.796
# 19 0.188 0.896
# 119 0.115 0.896
# 20 0.307 0.1
# 120 0.188 0.1
# 21 0.307 0.199
# 121 0.188 0.199
# 22 0.307 0.299
# 122 0.188 0.299
# 23 0.307 0.349
# 123 0.188 0.349
# 24 0.307 0.398
# 124 0.188 0.398
# 25 0.307 0.498
# 125 0.188 0.498
# 26 0.307 0.597
# 126 0.188 0.597
# 27 0.307 0.697
# 127 0.188 0.697
# 28 0.307 0.796
# 128 0.188 0.796
# 29 0.307 0.896
# 129 0.188 0.896
# 30 0.403 0.1
# 130 0.307 0.1
# 31 0.403 0.199
# 131 0.307 0.199
# 32 0.403 0.299
# 132 0.307 0.299
# 33 0.403 0.349
# 133 0.307 0.349
# 34 0.403 0.398
# 134 0.307 0.398
# 35 0.403 0.498
# 135 0.307 0.498
# 36 0.403 0.597
# 136 0.307 0.597
# 37 0.403 0.697
# 137 0.307 0.697
# 38 0.403 0.796
# 138 0.307 0.796
# 39 0.403 0.896
# 139 0.307 0.896
# 40 0.5 0.1
# 140 0.403 0.1
# 41 0.5 0.199
# 141 0.403 0.199
# 42 0.5 0.299
# 142 0.403 0.299
# 43 0.5 0.349
# 143 0.403 0.349
# 44 0.5 0.398
# 144 0.403 0.398
# 45 0.5 0.498
# 145 0.403 0.498
# 46 0.5 0.597
# 146 0.403 0.597
# 47 0.5 0.697
# 147 0.403 0.697
# 48 0.5 0.796
# 148 0.403 0.796
# 49 0.5 0.896
# 149 0.403 0.896
# 50 0.597 0.1
# 150 0.5 0.1
# 51 0.597 0.199
# 151 0.5 0.199
# 52 0.597 0.299
# 152 0.5 0.299
# 53 0.597 0.349
# 153 0.5 0.349
# 54 0.597 0.398
# 154 0.5 0.398
# 55 0.597 0.498
# 155 0.5 0.498
# 56 0.597 0.597
# 156 0.5 0.597
# 57 0.597 0.697
# 157 0.5 0.697
# 58 0.597 0.796
# 158 0.5 0.796
# 59 0.597 0.896
# 159 0.5 0.896
# 60 0.693 0.1
# 160 0.597 0.1
# 61 0.693 0.199
# 161 0.597 0.199
# 62 0.693 0.299
# 162 0.597 0.299
# 63 0.693 0.349
# 163 0.597 0.349
# 64 0.693 0.398
# 164 0.597 0.398
# 65 0.693 0.498
# 165 0.597 0.498
# 66 0.693 0.597
# 166 0.597 0.597
# 67 0.693 0.697
# 167 0.597 0.697
# 68 0.693 0.796
# 168 0.597 0.796
# 69 0.693 0.896
# 169 0.597 0.896
# 70 0.812 0.1
# 170 0.693 0.1
# 71 0.812 0.199
# 171 0.693 0.199
# 72 0.812 0.299
# 172 0.693 0.299
# 73 0.812 0.349
# 173 0.693 0.349
# 74 0.812 0.398
# 174 0.693 0.398
# 75 0.812 0.498
# 175 0.693 0.498
# 76 0.812 0.597
# 176 0.693 0.597
# 77 0.812 0.697
# 177 0.693 0.697
# 78 0.812 0.796
# 178 0.693 0.796
# 79 0.812 0.896
# 179 0.693 0.896
# 80 0.885 0.1
# 180 0.812 0.1
# 81 0.885 0.199
# 181 0.812 0.199
# 82 0.885 0.299
# 182 0.812 0.299
# 83 0.885 0.349
# 183 0.812 0.349
# 84 0.885 0.398
# 184 0.812 0.398
# 85 0.885 0.498
# 185 0.812 0.498
# 86 0.885 0.597
# 186 0.812 0.597
# 87 0.885 0.697
# 187 0.812 0.697
# 88 0.885 0.796
# 188 0.812 0.796
# 89 0.885 0.896
# 189 0.812 0.896
# 90 1.0 0.1
# 190 0.885 0.1
# 91 1.0 0.199
# 191 0.885 0.199
# 92 1.0 0.299
# 192 0.885 0.299
# 93 1.0 0.349
# 193 0.885 0.349
# 94 1.0 0.398
# 194 0.885 0.398
# 95 1.0 0.498
# 195 0.885 0.498
# 96 1.0 0.597
# 196 0.885 0.597
# 97 1.0 0.697
# 197 0.885 0.697
# 98 1.0 0.796
# 198 0.885 0.796
# 99 1.0 0.896
# 199 0.885 0.896
# 0 0.115 0.1
# 100 0 0.1
# 1 0.115 0.199
# 101 0 0.199
# 2 0.115 0.299
# 102 0 0.299
# 3 0.115 0.349
# 103 0 0.349
# 4 0.115 0.398
# 104 0 0.398
# 5 0.115 0.498
# 105 0 0.498
# 6 0.115 0.597
# 106 0 0.597
# 7 0.115 0.697
# 107 0 0.697
# 8 0.115 0.796
# 108 0 0.796
# 9 0.115 0.896
# 109 0 0.896
# 10 0.188 0.1
# 110 0.115 0.1
# 11 0.188 0.199
# 111 0.115 0.199
# 12 0.188 0.299
# 112 0.115 0.299
# 13 0.188 0.349
# 113 0.115 0.349
# 14 0.188 0.398
# 114 0.115 0.398
# 15 0.188 0.498
# 115 0.115 0.498
# 16 0.188 0.597
# 116 0.115 0.597
# 17 0.188 0.697
# 117 0.115 0.697
# 18 0.188 0.796
# 118 0.115 0.796
# 19 0.188 0.896
# 119 0.115 0.896
# 20 0.307 0.1
# 120 0.188 0.1
# 21 0.307 0.199
# 121 0.188 0.199
# 22 0.307 0.299
# 122 0.188 0.299
# 23 0.307 0.349
# 123 0.188 0.349
# 24 0.307 0.398
# 124 0.188 0.398
# 25 0.307 0.498
# 125 0.188 0.498
# 26 0.307 0.597
# 126 0.188 0.597
# 27 0.307 0.697
# 127 0.188 0.697
# 28 0.307 0.796
# 128 0.188 0.796
# 29 0.307 0.896
# 129 0.188 0.896
# 30 0.403 0.1
# 130 0.307 0.1
# 31 0.403 0.199
# 131 0.307 0.199
# 32 0.403 0.299
# 132 0.307 0.299
# 33 0.403 0.349
# 133 0.307 0.349
# 34 0.403 0.398
# 134 0.307 0.398
# 35 0.403 0.498
# 135 0.307 0.498
# 36 0.403 0.597
# 136 0.307 0.597
# 37 0.403 0.697
# 137 0.307 0.697
# 38 0.403 0.796
# 138 0.307 0.796
# 39 0.403 0.896
# 139 0.307 0.896
# 40 0.5 0.1
# 140 0.403 0.1
# 41 0.5 0.199
# 141 0.403 0.199
# 42 0.5 0.299
# 142 0.403 0.299
# 43 0.5 0.349
# 143 0.403 0.349
# 44 0.5 0.398
# 144 0.403 0.398
# 45 0.5 0.498
# 145 0.403 0.498
# 46 0.5 0.597
# 146 0.403 0.597
# 47 0.5 0.697
# 147 0.403 0.697
# 48 0.5 0.796
# 148 0.403 0.796
# 49 0.5 0.896
# 149 0.403 0.896
# 50 0.597 0.1
# 150 0.5 0.1
# 51 0.597 0.199
# 151 0.5 0.199
# 52 0.597 0.299
# 152 0.5 0.299
# 53 0.597 0.349
# 153 0.5 0.349
# 54 0.597 0.398
# 154 0.5 0.398
# 55 0.597 0.498
# 155 0.5 0.498
# 56 0.597 0.597
# 156 0.5 0.597
# 57 0.597 0.697
# 157 0.5 0.697
# 58 0.597 0.796
# 158 0.5 0.796
# 59 0.597 0.896
# 159 0.5 0.896
# 60 0.693 0.1
# 160 0.597 0.1
# 61 0.693 0.199
# 161 0.597 0.199
# 62 0.693 0.299
# 162 0.597 0.299
# 63 0.693 0.349
# 163 0.597 0.349
# 64 0.693 0.398
# 164 0.597 0.398
# 65 0.693 0.498
# 165 0.597 0.498
# 66 0.693 0.597
# 166 0.597 0.597
# 67 0.693 0.697
# 167 0.597 0.697
# 68 0.693 0.796
# 168 0.597 0.796
# 69 0.693 0.896
# 169 0.597 0.896
# 70 0.812 0.1
# 170 0.693 0.1
# 71 0.812 0.199
# 171 0.693 0.199
# 72 0.812 0.299
# 172 0.693 0.299
# 73 0.812 0.349
# 173 0.693 0.349
# 74 0.812 0.398
# 174 0.693 0.398
# 75 0.812 0.498
# 175 0.693 0.498
# 76 0.812 0.597
# 176 0.693 0.597
# 77 0.812 0.697
# 177 0.693 0.697
# 78 0.812 0.796
# 178 0.693 0.796
# 79 0.812 0.896
# 179 0.693 0.896
# 80 0.885 0.1
# 180 0.812 0.1
# 81 0.885 0.199
# 181 0.812 0.199
# 82 0.885 0.299
# 182 0.812 0.299
# 83 0.885 0.349
# 183 0.812 0.349
# 84 0.885 0.398
# 184 0.812 0.398
# 85 0.885 0.498
# 185 0.812 0.498
# 86 0.885 0.597
# 186 0.812 0.597
# 87 0.885 0.697
# 187 0.812 0.697
# 88 0.885 0.796
# 188 0.812 0.796
# 89 0.885 0.896
# 189 0.812 0.896
# 90 1.0 0.1
# 190 0.885 0.1
# 91 1.0 0.199
# 191 0.885 0.199
# 92 1.0 0.299
# 192 0.885 0.299
# 93 1.0 0.349
# 193 0.885 0.349
# 94 1.0 0.398
# 194 0.885 0.398
# 95 1.0 0.498
# 195 0.885 0.498
# 96 1.0 0.597
# 196 0.885 0.597
# 97 1.0 0.697
# 197 0.885 0.697
# 98 1.0 0.796
# 198 0.885 0.796
# 99 1.0 0.896
# 199 0.885 0.896
# 0 0.115 0.1
# 100 0 0.1
# 1 0.115 0.199
# 101 0 0.199
# 2 0.115 0.299
# 102 0 0.299
# 3 0.115 0.349
# 103 0 0.349
# 4 0.115 0.398
# 104 0 0.398
# 5 0.115 0.498
# 105 0 0.498
# 6 0.115 0.597
# 106 0 0.597
# 7 0.115 0.697
# 107 0 0.697
# 8 0.115 0.796
# 108 0 0.796
# 9 0.115 0.896
# 109 0 0.896
# 10 0.188 0.1
# 110 0.115 0.1
# 11 0.188 0.199
# 111 0.115 0.199
# 12 0.188 0.299
# 112 0.115 0.299
# 13 0.188 0.349
# 113 0.115 0.349
# 14 0.188 0.398
# 114 0.115 0.398
# 15 0.188 0.498
# 115 0.115 0.498
# 16 0.188 0.597
# 116 0.115 0.597
# 17 0.188 0.697
# 117 0.115 0.697
# 18 0.188 0.796
# 118 0.115 0.796
# 19 0.188 0.896
# 119 0.115 0.896
# 20 0.307 0.1
# 120 0.188 0.1
# 21 0.307 0.199
# 121 0.188 0.199
# 22 0.307 0.299
# 122 0.188 0.299
# 23 0.307 0.349
# 123 0.188 0.349
# 24 0.307 0.398
# 124 0.188 0.398
# 25 0.307 0.498
# 125 0.188 0.498
# 26 0.307 0.597
# 126 0.188 0.597
# 27 0.307 0.697
# 127 0.188 0.697
# 28 0.307 0.796
# 128 0.188 0.796
# 29 0.307 0.896
# 129 0.188 0.896
# 30 0.403 0.1
# 130 0.307 0.1
# 31 0.403 0.199
# 131 0.307 0.199
# 32 0.403 0.299
# 132 0.307 0.299
# 33 0.403 0.349
# 133 0.307 0.349
# 34 0.403 0.398
# 134 0.307 0.398
# 35 0.403 0.498
# 135 0.307 0.498
# 36 0.403 0.597
# 136 0.307 0.597
# 37 0.403 0.697
# 137 0.307 0.697
# 38 0.403 0.796
# 138 0.307 0.796
# 39 0.403 0.896
# 139 0.307 0.896
# 40 0.5 0.1
# 140 0.403 0.1
# 41 0.5 0.199
# 141 0.403 0.199
# 42 0.5 0.299
# 142 0.403 0.299
# 43 0.5 0.349
# 143 0.403 0.349
# 44 0.5 0.398
# 144 0.403 0.398
# 45 0.5 0.498
# 145 0.403 0.498
# 46 0.5 0.597
# 146 0.403 0.597
# 47 0.5 0.697
# 147 0.403 0.697
# 48 0.5 0.796
# 148 0.403 0.796
# 49 0.5 0.896
# 149 0.403 0.896
# 50 0.597 0.1
# 150 0.5 0.1
# 51 0.597 0.199
# 151 0.5 0.199
# 52 0.597 0.299
# 152 0.5 0.299
# 53 0.597 0.349
# 153 0.5 0.349
# 54 0.597 0.398
# 154 0.5 0.398
# 55 0.597 0.498
# 155 0.5 0.498
# 56 0.597 0.597
# 156 0.5 0.597
# 57 0.597 0.697
# 157 0.5 0.697
# 58 0.597 0.796
# 158 0.5 0.796
# 59 0.597 0.896
# 159 0.5 0.896
# 60 0.693 0.1
# 160 0.597 0.1
# 61 0.693 0.199
# 161 0.597 0.199
# 62 0.693 0.299
# 162 0.597 0.299
# 63 0.693 0.349
# 163 0.597 0.349
# 64 0.693 0.398
# 164 0.597 0.398
# 65 0.693 0.498
# 165 0.597 0.498
# 66 0.693 0.597
# 166 0.597 0.597
# 67 0.693 0.697
# 167 0.597 0.697
# 68 0.693 0.796
# 168 0.597 0.796
# 69 0.693 0.896
# 169 0.597 0.896
# 70 0.812 0.1
# 170 0.693 0.1
# 71 0.812 0.199
# 171 0.693 0.199
# 72 0.812 0.299
# 172 0.693 0.299
# 73 0.812 0.349
# 173 0.693 0.349
# 74 0.812 0.398
# 174 0.693 0.398
# 75 0.812 0.498
# 175 0.693 0.498
# 76 0.812 0.597
# 176 0.693 0.597
# 77 0.812 0.697
# 177 0.693 0.697
# 78 0.812 0.796
# 178 0.693 0.796
# 79 0.812 0.896
# 179 0.693 0.896
# 80 0.885 0.1
# 180 0.812 0.1
# 81 0.885 0.199
# 181 0.812 0.199
# 82 0.885 0.299
# 182 0.812 0.299
# 83 0.885 0.349
# 183 0.812 0.349
# 84 0.885 0.398
# 184 0.812 0.398
# 85 0.885 0.498
# 185 0.812 0.498
# 86 0.885 0.597
# 186 0.812 0.597
# 87 0.885 0.697
# 187 0.812 0.697
# 88 0.885 0.796
# 188 0.812 0.796
# 89 0.885 0.896
# 189 0.812 0.896
# 90 1.0 0.1
# 190 0.885 0.1
# 91 1.0 0.199
# 191 0.885 0.199
# 92 1.0 0.299
# 192 0.885 0.299
# 93 1.0 0.349
# 193 0.885 0.349
# 94 1.0 0.398
# 194 0.885 0.398
# 95 1.0 0.498
# 195 0.885 0.498
# 96 1.0 0.597
# 196 0.885 0.597
# 97 1.0 0.697
# 197 0.885 0.697
# 98 1.0 0.796
# 198 0.885 0.796
# 99 1.0 0.896
# 199 0.885 0.896
# 0 0.115 0.1
# 100 0 0.1
# 1 0.115 0.199
# 101 0 0.199
# 2 0.115 0.299
# 102 0 0.299
# 3 0.115 0.349
# 103 0 0.349
# 4 0.115 0.398
# 104 0 0.398
# 5 0.115 0.498
# 105 0 0.498
# 6 0.115 0.597
# 106 0 0.597
# 7 0.115 0.697
# 107 0 0.697
# 8 0.115 0.796
# 108 0 0.796
# 9 0.115 0.896
# 109 0 0.896
# 10 0.188 0.1
# 110 0.115 0.1
# 11 0.188 0.199
# 111 0.115 0.199
# 12 0.188 0.299
# 112 0.115 0.299
# 13 0.188 0.349
# 113 0.115 0.349
# 14 0.188 0.398
# 114 0.115 0.398
# 15 0.188 0.498
# 115 0.115 0.498
# 16 0.188 0.597
# 116 0.115 0.597
# 17 0.188 0.697
# 117 0.115 0.697
# 18 0.188 0.796
# 118 0.115 0.796
# 19 0.188 0.896
# 119 0.115 0.896
# 20 0.307 0.1
# 120 0.188 0.1
# 21 0.307 0.199
# 121 0.188 0.199
# 22 0.307 0.299
# 122 0.188 0.299
# 23 0.307 0.349
# 123 0.188 0.349
# 24 0.307 0.398
# 124 0.188 0.398
# 25 0.307 0.498
# 125 0.188 0.498
# 26 0.307 0.597
# 126 0.188 0.597
# 27 0.307 0.697
# 127 0.188 0.697
# 28 0.307 0.796
# 128 0.188 0.796
# 29 0.307 0.896
# 129 0.188 0.896
# 30 0.403 0.1
# 130 0.307 0.1
# 31 0.403 0.199
# 131 0.307 0.199
# 32 0.403 0.299
# 132 0.307 0.299
# 33 0.403 0.349
# 133 0.307 0.349
# 34 0.403 0.398
# 134 0.307 0.398
# 35 0.403 0.498
# 135 0.307 0.498
# 36 0.403 0.597
# 136 0.307 0.597
# 37 0.403 0.697
# 137 0.307 0.697
# 38 0.403 0.796
# 138 0.307 0.796
# 39 0.403 0.896
# 139 0.307 0.896
# 40 0.5 0.1
# 140 0.403 0.1
# 41 0.5 0.199
# 141 0.403 0.199
# 42 0.5 0.299
# 142 0.403 0.299
# 43 0.5 0.349
# 143 0.403 0.349
# 44 0.5 0.398
# 144 0.403 0.398
# 45 0.5 0.498
# 145 0.403 0.498
# 46 0.5 0.597
# 146 0.403 0.597
# 47 0.5 0.697
# 147 0.403 0.697
# 48 0.5 0.796
# 148 0.403 0.796
# 49 0.5 0.896
# 149 0.403 0.896
# 50 0.597 0.1
# 150 0.5 0.1
# 51 0.597 0.199
# 151 0.5 0.199
# 52 0.597 0.299
# 152 0.5 0.299
# 53 0.597 0.349
# 153 0.5 0.349
# 54 0.597 0.398
# 154 0.5 0.398
# 55 0.597 0.498
# 155 0.5 0.498
# 56 0.597 0.597
# 156 0.5 0.597
# 57 0.597 0.697
# 157 0.5 0.697
# 58 0.597 0.796
# 158 0.5 0.796
# 59 0.597 0.896
# 159 0.5 0.896
# 60 0.693 0.1
# 160 0.597 0.1
# 61 0.693 0.199
# 161 0.597 0.199
# 62 0.693 0.299
# 162 0.597 0.299
# 63 0.693 0.349
# 163 0.597 0.349
# 64 0.693 0.398
# 164 0.597 0.398
# 65 0.693 0.498
# 165 0.597 0.498
# 66 0.693 0.597
# 166 0.597 0.597
# 67 0.693 0.697
# 167 0.597 0.697
# 68 0.693 0.796
# 168 0.597 0.796
# 69 0.693 0.896
# 169 0.597 0.896
# 70 0.812 0.1
# 170 0.693 0.1
# 71 0.812 0.199
# 171 0.693 0.199
# 72 0.812 0.299
# 172 0.693 0.299
# 73 0.812 0.349
# 173 0.693 0.349
# 74 0.812 0.398
# 174 0.693 0.398
# 75 0.812 0.498
# 175 0.693 0.498
# 76 0.812 0.597
# 176 0.693 0.597
# 77 0.812 0.697
# 177 0.693 0.697
# 78 0.812 0.796
# 178 0.693 0.796
# 79 0.812 0.896
# 179 0.693 0.896
# 80 0.885 0.1
# 180 0.812 0.1
# 81 0.885 0.199
# 181 0.812 0.199
# 82 0.885 0.299
# 182 0.812 0.299
# 83 0.885 0.349
# 183 0.812 0.349
# 84 0.885 0.398
# 184 0.812 0.398
# 85 0.885 0.498
# 185 0.812 0.498
# 86 0.885 0.597
# 186 0.812 0.597
# 87 0.885 0.697
# 187 0.812 0.697
# 88 0.885 0.796
# 188 0.812 0.796
# 89 0.885 0.896
# 189 0.812 0.896
# 90 1.0 0.1
# 190 0.885 0.1
# 91 1.0 0.199
# 191 0.885 0.199
# 92 1.0 0.299
# 192 0.885 0.299
# 93 1.0 0.349
# 193 0.885 0.349
# 94 1.0 0.398
# 194 0.885 0.398
# 95 1.0 0.498
# 195 0.885 0.498
# 96 1.0 0.597
# 196 0.885 0.597
# 97 1.0 0.697
# 197 0.885 0.697
# 98 1.0 0.796
# 198 0.885 0.796
# 99 1.0 0.896
# 199 0.885 0.896
# 0 0.115 0.1
# 100 0 0.1
# 1 0.115 0.199
# 101 0 0.199
# 2 0.115 0.299
# 102 0 0.299
# 3 0.115 0.349
# 103 0 0.349
# 4 0.115 0.398
# 104 0 0.398
# 5 0.115 0.498
# 105 0 0.498
# 6 0.115 0.597
# 106 0 0.597
# 7 0.115 0.697
# 107 0 0.697
# 8 0.115 0.796
# 108 0 0.796
# 9 0.115 0.896
# 109 0 0.896
# 10 0.188 0.1
# 110 0.115 0.1
# 11 0.188 0.199
# 111 0.115 0.199
# 12 0.188 0.299
# 112 0.115 0.299
# 13 0.188 0.349
# 113 0.115 0.349
# 14 0.188 0.398
# 114 0.115 0.398
# 15 0.188 0.498
# 115 0.115 0.498
# 16 0.188 0.597
# 116 0.115 0.597
# 17 0.188 0.697
# 117 0.115 0.697
# 18 0.188 0.796
# 118 0.115 0.796
# 19 0.188 0.896
# 119 0.115 0.896
# 20 0.307 0.1
# 120 0.188 0.1
# 21 0.307 0.199
# 121 0.188 0.199
# 22 0.307 0.299
# 122 0.188 0.299
# 23 0.307 0.349
# 123 0.188 0.349
# 24 0.307 0.398
# 124 0.188 0.398
# 25 0.307 0.498
# 125 0.188 0.498
# 26 0.307 0.597
# 126 0.188 0.597
# 27 0.307 0.697
# 127 0.188 0.697
# 28 0.307 0.796
# 128 0.188 0.796
# 29 0.307 0.896
# 129 0.188 0.896
# 30 0.403 0.1
# 130 0.307 0.1
# 31 0.403 0.199
# 131 0.307 0.199
# 32 0.403 0.299
# 132 0.307 0.299
# 33 0.403 0.349
# 133 0.307 0.349
# 34 0.403 0.398
# 134 0.307 0.398
# 35 0.403 0.498
# 135 0.307 0.498
# 36 0.403 0.597
# 136 0.307 0.597
# 37 0.403 0.697
# 137 0.307 0.697
# 38 0.403 0.796
# 138 0.307 0.796
# 39 0.403 0.896
# 139 0.307 0.896
# 40 0.5 0.1
# 140 0.403 0.1
# 41 0.5 0.199
# 141 0.403 0.199
# 42 0.5 0.299
# 142 0.403 0.299
# 43 0.5 0.349
# 143 0.403 0.349
# 44 0.5 0.398
# 144 0.403 0.398
# 45 0.5 0.498
# 145 0.403 0.498
# 46 0.5 0.597
# 146 0.403 0.597
# 47 0.5 0.697
# 147 0.403 0.697
# 48 0.5 0.796
# 148 0.403 0.796
# 49 0.5 0.896
# 149 0.403 0.896
# 50 0.597 0.1
# 150 0.5 0.1
# 51 0.597 0.199
# 151 0.5 0.199
# 52 0.597 0.299
# 152 0.5 0.299
# 53 0.597 0.349
# 153 0.5 0.349
# 54 0.597 0.398
# 154 0.5 0.398
# 55 0.597 0.498
# 155 0.5 0.498
# 56 0.597 0.597
# 156 0.5 0.597
# 57 0.597 0.697
# 157 0.5 0.697
# 58 0.597 0.796
# 158 0.5 0.796
# 59 0.597 0.896
# 159 0.5 0.896
# 60 0.693 0.1
# 160 0.597 0.1
# 61 0.693 0.199
# 161 0.597 0.199
# 62 0.693 0.299
# 162 0.597 0.299
# 63 0.693 0.349
# 163 0.597 0.349
# 64 0.693 0.398
# 164 0.597 0.398
# 65 0.693 0.498
# 165 0.597 0.498
# 66 0.693 0.597
# 166 0.597 0.597
# 67 0.693 0.697
# 167 0.597 0.697
# 68 0.693 0.796
# 168 0.597 0.796
# 69 0.693 0.896
# 169 0.597 0.896
# 70 0.812 0.1
# 170 0.693 0.1
# 71 0.812 0.199
# 171 0.693 0.199
# 72 0.812 0.299
# 172 0.693 0.299
# 73 0.812 0.349
# 173 0.693 0.349
# 74 0.812 0.398
# 174 0.693 0.398
# 75 0.812 0.498
# 175 0.693 0.498
# 76 0.812 0.597
# 176 0.693 0.597
# 77 0.812 0.697
# 177 0.693 0.697
# 78 0.812 0.796
# 178 0.693 0.796
# 79 0.812 0.896
# 179 0.693 0.896
# 80 0.885 0.1
# 180 0.812 0.1
# 81 0.885 0.199
# 181 0.812 0.199
# 82 0.885 0.299
# 182 0.812 0.299
# 83 0.885 0.349
# 183 0.812 0.349
# 84 0.885 0.398
# 184 0.812 0.398
# 85 0.885 0.498
# 185 0.812 0.498
# 86 0.885 0.597
# 186 0.812 0.597
# 87 0.885 0.697
# 187 0.812 0.697
# 88 0.885 0.796
# 188 0.812 0.796
# 89 0.885 0.896
# 189 0.812 0.896
# 90 1.0 0.1
# 190 0.885 0.1
# 91 1.0 0.199
# 191 0.885 0.199
# 92 1.0 0.299
# 192 0.885 0.299
# 93 1.0 0.349
# 193 0.885 0.349
# 94 1.0 0.398
# 194 0.885 0.398
# 95 1.0 0.498
# 195 0.885 0.498
# 96 1.0 0.597
# 196 0.885 0.597
# 97 1.0 0.697
# 197 0.885 0.697
# 98 1.0 0.796
# 198 0.885 0.796
# 99 1.0 0.896
# 199 0.885 0.896

# %% [markdown]
# ## Identifiability analysis

# %%
def read_one_measure(key, scale_option =None):
    
    jaco_file = "./jaco_and_var_10t10/"+key+"_"+scale_option
    jacobian = load_pickle(jaco_file)

    var_file = "./jaco_and_var_10t10/Var_"+key+"_"+scale_option
    var = load_pickle(var_file)
    
    return jacobian, var

# %%
def compute_fim(overall_jac, overall_var, z_pos_idx=[10,20,30,40], verbose=True):
    """
    
    """

    jaco = np.zeros((len(z_pos_idx), n_para))
    var = np.zeros((len(z_pos_idx), len(z_pos_idx)))
    #var = np.asarray([0]*len(z_pos_idx))
    
    
    for i in range(len(z_pos_idx)):
        var[i,i] = overall_var[z_pos_idx[i]]
        for p in range(n_para):
            jaco[i,p] = overall_jac[z_pos_idx[i]][p]
        
    var_inv = np.linalg.inv(var)
        
    fim = jaco.T@var_inv@jaco
    
    if verbose:
        print("===total FIM===")
        print("log(10) determinant:", np.log10(np.linalg.det(fim)))
        print("log(10) trace:", np.log10(np.trace(fim)))
        print("eig:", np.linalg.eigvals(fim))
        print("FIM:", fim)

    return fim

# %%
test1 = list(range(80, 90))
ads_output = list(range(90, 100))
des_output = list(range(100, 110))

test2 = [0, 10, 20, 30]
chosen = [109, 119]

CCO2_jac, CCO2_var = read_one_measure("Tg", scale_option="scale_parameter")


compute_fim(CCO2_jac, CCO2_var, z_pos_idx=[25])
# Out:
# ===total FIM===
# log(10) determinant: -inf
# log(10) trace: 9.218818205990042
# eig: [ 2.38418579e-07  1.65507701e+09  2.57528306e-11 -1.66051939e-11
#  -1.19353442e-16]
# FIM: [[ 1.27489104e+00 -7.82011685e+00  4.59343070e+04  2.86745903e+02
#    5.07221648e-01]
#  [-7.82011685e+00  4.79681994e+01 -2.81758705e+05 -1.75888480e+03
#   -3.11127182e+00]
#  [ 4.59343070e+04 -2.81758705e+05  1.65501247e+09  1.03314510e+07
#    1.82751892e+04]
#  [ 2.86745903e+02 -1.75888480e+03  1.03314510e+07  6.44943059e+04
#    1.14083263e+02]
#  [ 5.07221648e-01 -3.11127182e+00  1.82751892e+04  1.14083263e+02
#    2.01800619e-01]]
# /tmp/ipykernel_408750/243587232.py:22: RuntimeWarning: divide by zero encountered in log10
#   print("log(10) determinant:", np.log10(np.linalg.det(fim)))
# array([[ 1.27489104e+00, -7.82011685e+00,  4.59343070e+04,
#          2.86745903e+02,  5.07221648e-01],
#        [-7.82011685e+00,  4.79681994e+01, -2.81758705e+05,
#         -1.75888480e+03, -3.11127182e+00],
#        [ 4.59343070e+04, -2.81758705e+05,  1.65501247e+09,
#          1.03314510e+07,  1.82751892e+04],
#        [ 2.86745903e+02, -1.75888480e+03,  1.03314510e+07,
#          6.44943059e+04,  1.14083263e+02],
#        [ 5.07221648e-01, -3.11127182e+00,  1.82751892e+04,
#          1.14083263e+02,  2.01800619e-01]])

# %% [markdown]
# ## Ranking

# %% [markdown]
# ### rank all measurements

# %%
measure_keys = ["vg", 
                "Tg", 
                "Ts", 
                "P",
                "y_CO2"]

# %%
log10_det = []
log10_trace = []
original_trace= [] 
fim_collection = [] 

count = 0 
for key in measure_keys:
    key_jac, key_var = read_one_measure(key, scale_option="scale_parameter")

    if key=="vg":
        for j in range(90, 110):
            fim = compute_fim(key_jac, key_var, z_pos_idx=[j],verbose=False)
            fim_collection.append(fim)
            log10_det.append((np.log10(np.linalg.det(fim)), count))
            log10_trace.append((np.log10(np.trace(fim)), count))
            original_trace.append((np.trace(fim), count))
            count += 1 
    
    elif key=="P":
        for j in range(90):
            fim = compute_fim(key_jac, key_var, z_pos_idx=[j],verbose=False)
            fim_collection.append(fim)
            log10_det.append((np.log10(np.linalg.det(fim)), count))
            log10_trace.append((np.log10(np.trace(fim)), count))
            original_trace.append((np.trace(fim), count))
            count += 1 
        for j in range(110,200):
            fim = compute_fim(key_jac, key_var, z_pos_idx=[j],verbose=False)
            fim_collection.append(fim)
            log10_det.append((np.log10(np.linalg.det(fim)), count))
            log10_trace.append((np.log10(np.trace(fim)), count))
            original_trace.append((np.trace(fim), count))
            count += 1 
    
    else:
        for j in range(200):
            fim = compute_fim(key_jac, key_var, z_pos_idx=[j],verbose=False)
            fim_collection.append(fim)
            log10_det.append((np.log10(np.linalg.det(fim)), count))
            log10_trace.append((np.log10(np.trace(fim)), count))
            original_trace.append((np.trace(fim), count))
            count += 1
# Out:
# /tmp/ipykernel_408750/2756802933.py:14: RuntimeWarning: divide by zero encountered in log10
#   log10_det.append((np.log10(np.linalg.det(fim)), count))
# /tmp/ipykernel_408750/2756802933.py:14: RuntimeWarning: invalid value encountered in log10
#   log10_det.append((np.log10(np.linalg.det(fim)), count))
# /tmp/ipykernel_408750/2756802933.py:39: RuntimeWarning: divide by zero encountered in log10
#   log10_det.append((np.log10(np.linalg.det(fim)), count))
# /tmp/ipykernel_408750/2756802933.py:39: RuntimeWarning: invalid value encountered in log10
#   log10_det.append((np.log10(np.linalg.det(fim)), count))
# /tmp/ipykernel_408750/2756802933.py:40: RuntimeWarning: divide by zero encountered in log10
#   log10_trace.append((np.log10(np.trace(fim)), count))
# /tmp/ipykernel_408750/2756802933.py:23: RuntimeWarning: divide by zero encountered in log10
#   log10_det.append((np.log10(np.linalg.det(fim)), count))
# /tmp/ipykernel_408750/2756802933.py:23: RuntimeWarning: invalid value encountered in log10
#   log10_det.append((np.log10(np.linalg.det(fim)), count))
# /tmp/ipykernel_408750/2756802933.py:30: RuntimeWarning: divide by zero encountered in log10
#   log10_det.append((np.log10(np.linalg.det(fim)), count))
# /tmp/ipykernel_408750/2756802933.py:30: RuntimeWarning: invalid value encountered in log10
#   log10_det.append((np.log10(np.linalg.det(fim)), count))

# %%
#print(len(log10_det))
#print(len(log10_trace))
#print(log10_trace[1210])

# %%
log10_trace.sort(key=lambda x: -x[0])

#print(log10_trace)

# %%
trace_rank = []

for t, idx in log10_trace:
    trace_rank.append(idx)

# %%
measure_len = [20,200,200,180,200]
num_z_grid = 10

all_names = [] 

for i, item in enumerate(measure_keys): 
     
    if i==0: # vg 

        for k in range(measure_len[i]):
            
            name = [item]

            if k < num_z_grid:
                name.append("ads")
                name.append(str(9))
                name.append(str(k))

            else:
                k-=num_z_grid 
                name.append("des")
                name.append(str(0))
                name.append(str(k))
            
            all_names.append("_".join(name))
            
    elif i==3: # P 
                
        for k in range(measure_len[i]):
            
            name = [item] 
            
            if k < measure_len[i]//2:
                name.append("ads")
                name.append(str(k//num_z_grid))
                name.append(str(k%num_z_grid))
                
            elif k >= measure_len[i]//2:
                k -= measure_len[i]//2
                k += 10 
                name.append("des")
                name.append(str(k//num_z_grid))
                name.append(str(k%num_z_grid))
                
            all_names.append("_".join(name))
    
    else:

    
        for k in range(measure_len[i]):
            
            name = [item]

            if k < measure_len[i]//2: 
                name.append("ads")
                name.append(str(k//num_z_grid))
                name.append(str(k%num_z_grid))

            elif k>= measure_len[i]//2:

                k -= measure_len[i]//2
                name.append("des")
                name.append(str(k//num_z_grid))
                name.append(str(k%num_z_grid))

            all_names.append("_".join(name))

# %%
#print(all_names)

# %%
print(trace_rank[0])
print(log10_trace[0])
# Out:
# 245
# (9.222391021347903, 245)

# %%
for i in trace_rank:
    print(all_names[i])
# Out:
# Ts_ads_2_5
# Tg_ads_2_5
# Ts_des_9_4
# Tg_des_9_4
# Ts_des_8_6
# Tg_des_8_6
# y_CO2_des_2_3
# Ts_des_5_9
# Tg_des_5_9
# y_CO2_des_1_3
# y_CO2_des_3_3
# Ts_des_7_8
# Tg_des_7_8
# y_CO2_des_5_9
# y_CO2_des_0_3
# Ts_ads_0_0
# Tg_ads_0_0
# y_CO2_des_4_3
# Ts_ads_5_5
# Tg_ads_5_5
# Ts_des_9_5
# Tg_des_9_5
# Ts_des_6_9
# Tg_des_6_9
# Ts_ads_0_2
# y_CO2_des_0_4
# Tg_ads_0_2
# y_CO2_des_6_8
# Ts_ads_1_1
# Tg_ads_1_1
# y_CO2_des_4_9
# Ts_des_8_7
# Tg_des_8_7
# y_CO2_des_9_4
# y_CO2_des_1_4
# y_CO2_des_6_2
# y_CO2_des_5_3
# y_CO2_des_7_8
# Ts_des_4_9
# Tg_des_4_9
# Ts_des_7_9
# Tg_des_7_9
# Ts_ads_3_3
# Ts_des_8_0
# Tg_ads_3_3
# Tg_des_8_0
# Tg_des_0_6
# y_CO2_des_5_2
# y_CO2_des_2_4
# y_CO2_des_3_9
# y_CO2_des_8_6
# y_CO2_des_7_2
# y_CO2_des_5_8
# Ts_ads_0_3
# Tg_ads_0_3
# Ts_ads_4_2
# Ts_des_9_3
# Tg_ads_4_2
# Tg_des_9_3
# y_CO2_des_4_2
# Ts_ads_2_6
# Tg_ads_2_6
# Ts_ads_6_5
# Tg_ads_6_5
# Ts_des_8_4
# Tg_des_8_4
# Ts_ads_3_4
# Ts_ads_5_6
# Tg_ads_5_6
# Tg_ads_3_4
# Ts_ads_2_2
# Ts_ads_6_7
# Tg_ads_2_2
# Tg_ads_6_7
# y_CO2_des_6_9
# Tg_ads_3_5
# Ts_ads_3_5
# Ts_des_4_3
# Tg_des_4_3
# Ts_des_5_8
# Tg_des_5_8
# y_CO2_des_2_9
# Ts_des_5_3
# Tg_des_5_3
# Ts_des_1_4
# Tg_des_1_4
# Ts_des_7_2
# Ts_des_3_3
# Tg_des_3_3
# Tg_des_7_2
# Ts_ads_6_6
# y_CO2_des_3_2
# y_CO2_des_3_4
# Tg_ads_6_6
# Ts_des_4_4
# Tg_des_4_4
# Ts_des_3_9
# Ts_des_2_4
# Ts_des_3_4
# y_CO2_des_8_4
# Ts_des_9_6
# Tg_des_3_9
# Tg_des_2_4
# Tg_des_3_4
# Tg_des_9_6
# y_CO2_des_4_8
# y_CO2_des_1_9
# Ts_ads_4_3
# Tg_ads_4_3
# Ts_des_6_2
# Tg_des_6_2
# y_CO2_des_2_2
# y_CO2_des_1_2
# Tg_des_0_7
# y_CO2_des_0_9
# y_CO2_des_4_4
# y_CO2_des_6_3
# y_CO2_des_3_8
# y_CO2_des_0_2
# y_CO2_des_8_0
# Ts_ads_3_1
# Tg_ads_3_1
# Ts_des_2_3
# Tg_des_2_3
# Ts_des_5_4
# Ts_des_8_8
# Tg_des_5_4
# y_CO2_des_9_3
# Tg_des_8_8
# Ts_des_6_3
# Tg_des_6_3
# Ts_des_6_8
# Tg_des_6_8
# Ts_des_7_6
# Tg_des_7_6
# Ts_des_4_8
# Tg_des_4_8
# Ts_des_9_2
# Tg_des_9_2
# y_CO2_des_2_8
# Ts_des_2_9
# Tg_des_2_9
# y_CO2_des_7_4
# Tg_des_0_4
# y_CO2_des_8_3
# y_CO2_des_7_6
# Tg_ads_9_9
# y_CO2_des_5_4
# y_CO2_des_1_8
# y_CO2_des_7_3
# Ts_des_8_3
# Tg_des_8_3
# Ts_ads_5_3
# Tg_ads_5_3
# y_CO2_des_7_7
# y_CO2_des_9_2
# y_CO2_des_0_8
# Ts_ads_5_2
# Tg_ads_5_2
# Ts_des_1_9
# Ts_ads_7_6
# Tg_des_0_0
# Tg_des_1_9
# Tg_ads_7_6
# Ts_ads_3_2
# Tg_ads_3_2
# Tg_des_0_3
# y_CO2_des_6_6
# Ts_ads_2_0
# y_CO2_des_6_4
# Tg_ads_2_0
# Ts_des_3_8
# Tg_des_3_8
# Ts_ads_0_4
# Tg_ads_0_4
# Ts_ads_2_3
# Tg_ads_2_3
# Ts_ads_4_5
# Ts_des_9_7
# Tg_des_9_7
# Tg_ads_4_5
# y_CO2_des_6_7
# Ts_ads_5_4
# Tg_ads_5_4
# y_CO2_des_8_2
# Ts_ads_7_5
# Tg_ads_7_5
# Ts_ads_4_1
# Tg_ads_4_1
# Ts_des_1_5
# Tg_des_1_5
# Ts_des_7_4
# y_CO2_des_5_6
# Tg_des_7_4
# Tg_des_0_5
# Ts_ads_1_0
# Ts_des_6_6
# Tg_des_6_6
# Tg_ads_1_0
# y_CO2_des_5_7
# y_CO2_des_0_0
# Ts_ads_7_7
# Tg_ads_7_7
# Tg_des_0_9
# Ts_des_7_7
# Tg_des_7_7
# Ts_des_6_7
# Tg_des_6_7
# Ts_des_2_8
# Tg_des_2_8
# Ts_ads_5_9
# Tg_ads_5_9
# Ts_ads_7_9
# Tg_ads_7_9
# y_CO2_des_1_0
# Ts_des_9_0
# Tg_des_9_0
# y_CO2_des_4_6
# y_CO2_des_4_7
# Ts_des_8_9
# Tg_des_8_9
# y_CO2_des_2_0
# Ts_ads_2_7
# Tg_ads_2_7
# Ts_des_2_0
# Tg_des_2_0
# Ts_ads_5_7
# y_CO2_des_8_5
# Ts_des_1_0
# Tg_ads_5_7
# Tg_des_1_0
# Ts_des_8_2
# Tg_des_8_2
# Ts_ads_7_8
# Tg_ads_7_8
# y_CO2_des_7_9
# Ts_des_3_0
# Tg_des_3_0
# y_CO2_des_9_5
# y_CO2_des_3_7
# Ts_ads_8_8
# Tg_ads_8_8
# Ts_des_1_8
# Tg_des_1_8
# Ts_des_8_1
# Tg_des_8_1
# Ts_des_2_5
# Tg_des_2_5
# Ts_des_4_0
# Ts_ads_4_4
# Ts_ads_8_6
# Tg_ads_8_6
# Tg_des_4_0
# y_CO2_des_3_6
# Tg_ads_4_4
# Ts_des_7_3
# Tg_des_7_3
# Ts_ads_3_7
# y_CO2_des_3_0
# Tg_ads_3_7
# Ts_ads_6_3
# Tg_ads_6_3
# y_CO2_des_7_5
# y_CO2_des_2_7
# Ts_ads_8_9
# Tg_ads_8_9
# Ts_ads_8_7
# Tg_ads_8_7
# y_CO2_des_8_7
# y_CO2_des_0_7
# y_CO2_des_1_7
# Ts_ads_2_4
# Tg_ads_2_4
# Ts_des_5_0
# Tg_des_5_0
# Ts_ads_6_4
# Tg_ads_6_4
# y_CO2_ads_4_5
# Ts_des_1_3
# Tg_des_1_3
# y_CO2_des_2_6
# y_CO2_des_0_6
# Ts_ads_5_0
# Tg_ads_5_0
# Tg_des_0_1
# Ts_des_5_7
# Tg_des_5_7
# Ts_ads_1_3
# y_CO2_des_4_0
# Ts_des_5_6
# y_CO2_des_6_5
# Tg_des_5_6
# Tg_ads_1_3
# Tg_ads_6_2
# Ts_ads_6_2
# Ts_ads_4_7
# Tg_ads_4_7
# y_CO2_des_1_6
# y_CO2_des_7_0
# Tg_ads_1_4
# Ts_des_8_5
# Ts_ads_1_4
# Ts_ads_6_0
# Tg_ads_6_0
# Tg_des_8_5
# Ts_ads_4_6
# y_CO2_ads_2_5
# Ts_des_4_2
# Tg_ads_4_6
# Tg_des_4_2
# Tg_ads_8_5
# Ts_ads_8_5
# Tg_ads_2_1
# Ts_ads_2_1
# Tg_ads_1_2
# Ts_des_7_5
# Ts_ads_1_2
# Tg_des_7_5
# Ts_des_9_8
# Tg_des_9_8
# Ts_ads_0_1
# Tg_ads_0_1
# Ts_des_3_5
# Ts_des_6_0
# Tg_des_3_5
# y_CO2_ads_2_2
# Tg_des_6_0
# y_CO2_des_9_1
# y_CO2_des_0_5
# Ts_des_4_7
# Tg_des_4_7
# y_CO2_ads_3_5
# Ts_des_3_2
# Tg_des_3_2
# y_CO2_ads_0_0
# Tg_ads_3_0
# Ts_ads_3_0
# Tg_ads_3_6
# Ts_ads_3_6
# Ts_ads_6_8
# Tg_ads_6_8
# Tg_des_0_8
# Tg_ads_9_8
# Ts_des_9_1
# Tg_des_9_1
# Tg_ads_5_1
# Ts_ads_5_1
# y_CO2_des_9_0
# y_CO2_des_5_0
# Ts_des_1_1
# Tg_des_1_1
# Ts_des_7_1
# Tg_des_7_1
# Ts_des_4_6
# Tg_des_4_6
# y_CO2_ads_2_6
# Ts_des_2_1
# Ts_ads_4_0
# Tg_des_2_1
# vg_ads_9_5
# Tg_ads_4_0
# vg_des_0_4
# Ts_ads_4_8
# Tg_ads_4_8
# y_CO2_des_5_5
# y_CO2_ads_5_6
# y_CO2_ads_0_3
# Ts_des_3_1
# Tg_des_3_1
# Ts_ads_6_9
# Tg_ads_6_9
# Ts_des_3_7
# Tg_des_3_7
# y_CO2_ads_3_3
# Ts_des_4_5
# Tg_des_4_5
# Ts_des_2_2
# Ts_des_4_1
# Tg_des_2_2
# Tg_des_4_1
# Tg_ads_9_7
# vg_des_0_3
# Ts_ads_7_0
# Tg_ads_7_0
# y_CO2_ads_3_2
# Ts_ads_3_8
# Ts_ads_7_4
# Tg_ads_7_4
# Tg_ads_3_8
# Ts_des_6_5
# Tg_des_6_5
# Tg_ads_7_3
# Ts_ads_7_3
# Ts_des_5_1
# Tg_ads_9_6
# Tg_des_5_1
# vg_ads_9_9
# vg_des_0_8
# y_CO2_ads_7_9
# Ts_des_3_6
# Tg_des_3_6
# Ts_des_6_1
# Tg_des_6_1
# Ts_des_1_2
# Tg_des_1_2
# y_CO2_des_6_1
# Ts_ads_1_5
# Tg_ads_1_5
# Ts_ads_0_5
# Tg_ads_0_5
# Ts_des_2_7
# y_CO2_des_7_1
# Tg_des_2_7
# y_CO2_ads_1_1
# Ts_ads_5_8
# Tg_ads_5_8
# y_CO2_ads_2_1
# y_CO2_des_5_1
# Ts_ads_2_8
# Tg_ads_2_8
# y_CO2_ads_8_9
# y_CO2_ads_5_9
# vg_des_0_6
# y_CO2_des_9_6
# y_CO2_des_4_1
# Tg_ads_7_2
# Ts_ads_7_2
# vg_des_0_9
# y_CO2_ads_1_0
# y_CO2_des_3_1
# Ts_des_9_9
# Tg_des_9_9
# y_CO2_des_8_8
# y_CO2_ads_6_7
# y_CO2_des_2_1
# Ts_des_1_7
# Tg_des_1_7
# y_CO2_des_1_1
# y_CO2_ads_1_3
# y_CO2_des_4_5
# Ts_ads_8_0
# Tg_ads_8_0
# y_CO2_ads_5_5
# y_CO2_ads_2_3
# vg_des_0_0
# Tg_ads_9_5
# y_CO2_des_0_1
# y_CO2_ads_3_4
# y_CO2_ads_3_7
# vg_des_0_2
# y_CO2_ads_1_4
# y_CO2_ads_6_9
# Ts_ads_8_4
# Tg_ads_8_4
# vg_des_0_7
# Ts_des_7_0
# Tg_des_7_0
# vg_ads_9_2
# P_des_5_3
# P_des_4_3
# Tg_ads_8_3
# Ts_ads_8_3
# P_ads_6_5
# P_des_6_3
# Ts_des_5_5
# y_CO2_ads_1_2
# P_des_3_3
# P_ads_5_5
# Tg_des_5_5
# y_CO2_ads_7_8
# y_CO2_des_8_1
# Ts_ads_4_9
# Tg_ads_4_9
# y_CO2_ads_2_4
# y_CO2_ads_3_6
# Tg_des_2_6
# Ts_des_2_6
# P_ads_1_5
# P_des_7_3
# Ts_ads_3_9
# P_ads_7_5
# Tg_ads_3_9
# y_CO2_ads_0_4
# Tg_ads_6_1
# Ts_ads_6_1
# Tg_ads_8_2
# Ts_ads_8_2
# P_ads_3_5
# P_ads_3_3
# Tg_des_0_2
# y_CO2_ads_4_3
# y_CO2_ads_4_7
# P_des_2_3
# y_CO2_ads_6_6
# y_CO2_ads_5_7
# y_CO2_ads_4_4
# vg_ads_9_7
# Ts_ads_1_6
# Tg_ads_1_6
# vg_ads_9_8
# P_des_6_9
# P_ads_4_5
# y_CO2_des_3_5
# y_CO2_ads_2_0
# y_CO2_ads_4_8
# Tg_des_6_4
# P_des_7_9
# y_CO2_ads_4_2
# P_ads_5_6
# Ts_des_6_4
# y_CO2_ads_0_2
# y_CO2_ads_3_1
# P_des_3_4
# P_ads_8_5
# y_CO2_des_9_7
# P_ads_0_5
# y_CO2_ads_2_7
# P_des_4_4
# y_CO2_ads_5_8
# Ts_ads_2_9
# Tg_ads_2_9
# P_ads_3_4
# P_ads_2_5
# P_ads_1_1
# y_CO2_des_1_5
# P_des_2_4
# P_des_8_3
# y_CO2_ads_4_6
# y_CO2_des_6_0
# y_CO2_des_8_9
# P_ads_5_2
# P_des_5_4
# P_des_1_3
# y_CO2_ads_0_1
# Tg_ads_9_4
# P_ads_2_3
# P_ads_2_1
# P_ads_6_2
# P_ads_6_7
# P_des_5_9
# y_CO2_ads_6_5
# P_des_8_9
# P_ads_4_3
# P_ads_0_0
# Ts_ads_0_6
# Tg_ads_0_6
# P_ads_5_9
# P_ads_4_4
# Ts_ads_8_1
# Tg_ads_8_1
# P_ads_4_2
# P_des_1_4
# P_ads_8_9
# P_ads_7_9
# P_des_6_4
# P_ads_4_9
# Tg_ads_9_3
# P_des_8_8
# P_des_5_0
# y_CO2_ads_9_9
# P_ads_6_9
# P_des_4_0
# P_des_9_3
# P_ads_2_2
# Ts_ads_7_1
# P_des_6_0
# Tg_ads_7_1
# P_ads_4_6
# P_ads_7_2
# vg_ads_9_6
# P_des_3_0
# P_ads_3_9
# vg_ads_9_1
# P_des_9_9
# P_des_7_0
# Ts_des_5_2
# Tg_des_5_2
# P_des_7_2
# P_des_7_8
# y_CO2_ads_7_7
# Tg_ads_9_0
# P_ads_3_0
# vg_des_0_1
# y_CO2_ads_1_5
# Tg_ads_9_1
# P_ads_6_6
# P_des_8_2
# y_CO2_ads_3_8
# P_des_7_4
# y_CO2_ads_6_8
# y_CO2_ads_5_3
# P_ads_3_7
# P_des_4_9
# y_CO2_ads_5_4
# P_ads_7_7
# P_des_9_8
# P_ads_5_4
# P_ads_2_9
# P_ads_4_0
# P_des_2_0
# y_CO2_ads_8_8
# Ts_des_1_6
# P_ads_7_8
# P_ads_8_2
# Tg_des_1_6
# P_ads_1_0
# P_ads_2_7
# y_CO2_ads_7_6
# Ts_ads_1_7
# P_des_4_6
# Tg_ads_1_7
# P_des_6_2
# P_des_5_6
# P_des_3_8
# y_CO2_ads_5_2
# P_ads_2_4
# y_CO2_des_2_5
# P_ads_1_6
# y_CO2_ads_4_1
# P_ads_5_3
# P_des_3_6
# P_des_4_8
# Tg_ads_9_2
# P_des_6_6
# P_ads_2_0
# y_CO2_des_9_8
# P_des_8_0
# P_des_9_4
# P_des_1_0
# P_des_5_5
# P_des_2_8
# y_CO2_ads_3_0
# P_ads_1_9
# P_des_9_2
# P_des_4_5
# P_des_8_4
# P_des_6_5
# P_ads_5_0
# y_CO2_ads_0_5
# P_ads_3_1
# P_des_2_6
# P_des_8_7
# y_CO2_ads_7_5
# P_ads_8_7
# P_ads_5_1
# P_ads_0_6
# P_des_7_6
# P_des_3_5
# vg_ads_9_0
# P_ads_0_3
# y_CO2_ads_5_0
# y_CO2_ads_9_0
# vg_ads_9_4
# P_ads_3_6
# P_ads_8_8
# y_CO2_ads_8_0
# P_ads_5_7
# y_CO2_ads_7_0
# P_ads_6_8
# P_ads_6_1
# P_ads_0_1
# P_ads_6_4
# P_des_1_8
# y_CO2_ads_6_0
# P_des_5_8
# P_des_9_6
# P_ads_4_7
# y_CO2_ads_8_7
# P_des_5_2
# y_CO2_ads_4_9
# P_des_1_6
# P_des_7_5
# P_ads_0_9
# y_CO2_ads_2_8
# P_ads_1_3
# P_des_3_9
# Ts_ads_0_7
# P_des_9_7
# Tg_ads_0_7
# y_CO2_ads_8_6
# y_CO2_ads_6_4
# y_CO2_ads_6_3
# P_ads_0_4
# P_ads_7_1
# P_des_2_5
# P_ads_4_1
# y_CO2_ads_4_0
# P_des_7_7
# vg_ads_9_3
# y_CO2_ads_6_2
# P_ads_1_4
# P_des_6_8
# P_ads_6_0
# P_ads_6_3
# Tg_ads_0_9
# y_CO2_ads_9_8
# Ts_ads_0_9
# y_CO2_ads_8_5
# P_des_3_7
# y_CO2_ads_5_1
# P_ads_1_7
# P_des_4_7
# P_ads_8_1
# P_des_2_7
# Ts_ads_1_8
# Tg_ads_1_8
# y_CO2_des_9_9
# P_ads_7_4
# P_ads_8_6
# P_des_9_0
# P_des_2_2
# y_CO2_ads_3_9
# P_ads_3_2
# P_des_1_5
# y_CO2_ads_1_6
# P_ads_5_8
# P_des_1_7
# vg_des_0_5
# P_des_1_2
# y_CO2_ads_9_7
# P_ads_1_8
# P_ads_4_8
# P_des_9_5
# P_ads_3_8
# y_CO2_ads_7_4
# Tg_ads_1_9
# Ts_ads_1_9
# P_ads_0_7
# y_CO2_ads_7_3
# y_CO2_ads_9_6
# P_des_5_7
# P_des_9_1
# P_des_4_2
# P_des_3_2
# P_des_8_5
# y_CO2_ads_7_2
# P_ads_0_8
# y_CO2_ads_0_6
# P_ads_8_4
# Ts_ads_0_8
# Tg_ads_0_8
# P_des_1_9
# P_ads_2_8
# y_CO2_ads_9_5
# P_ads_1_2
# P_des_8_6
# y_CO2_ads_8_4
# P_ads_2_6
# y_CO2_ads_2_9
# y_CO2_ads_8_3
# P_ads_7_6
# P_des_4_1
# P_ads_0_2
# P_des_3_1
# P_des_6_7
# y_CO2_ads_6_1
# P_des_5_1
# y_CO2_ads_8_2
# y_CO2_ads_9_1
# P_des_2_1
# P_ads_8_0
# P_des_6_1
# P_ads_7_0
# P_ads_8_3
# P_des_1_1
# P_des_8_1
# y_CO2_ads_9_4
# y_CO2_ads_9_3
# y_CO2_ads_1_7
# P_des_2_9
# y_CO2_ads_8_1
# P_des_7_1
# y_CO2_ads_9_2
# P_ads_7_3
# y_CO2_ads_0_7
# y_CO2_ads_7_1
# y_CO2_ads_1_8
# y_CO2_ads_0_8
# y_CO2_ads_1_9
# y_CO2_ads_0_9
# Ts_des_0_2
# Ts_des_0_3
# Ts_des_0_4
# Ts_des_0_5
# Ts_des_0_6
# Ts_des_0_7
# Ts_des_0_8
# Ts_des_0_9
# Ts_des_0_0
# Ts_des_0_1
# Ts_ads_9_0
# Ts_ads_9_1
# Ts_ads_9_2
# Ts_ads_9_3
# Ts_ads_9_4
# Ts_ads_9_5
# Ts_ads_9_6
# Ts_ads_9_7
# Ts_ads_9_8
# Ts_ads_9_9

# %%
def save_pickle(data, name):
    file = open(name, "wb")
    pickle.dump(data, file)
    file.close()

save_pickle(all_names, "original_MO_rank")

# %%
for j in range(len(log10_det)):
    if log10_det[j][0] > 0.1:
        print(all_names[j], log10_det[j][1])

# %% [markdown]
# ### Initial solution generator

# %%
def names_to_idx(names):

    names_idx = [] 

    for n in names:
        names_idx.append(all_names.index(n))
    
    return names_idx

def compute_trace_from_idx(name):
    
    sol = names_to_idx(name)
    
    total_trace = sum(original_trace[i][0] for i in sol)
    total_fim = sum(fim_collection[i] for i in sol)
    
    
    print(total_trace)
    print(total_fim)
    print("trace:", format(np.trace(total_fim)))
    print("det:", np.linalg.det(total_fim))
    print("log10 trace:", format(np.log10(np.trace(total_fim))))
    print("log10 det:", np.log10(np.linalg.det(total_fim)))

# %%
benchmark = ["vg_ads_9_0", 
            "vg_ads_9_5", 
            #"vg_ads_9_9", 
            "vg_des_0_0", 
            "vg_des_0_5", 
            #"vg_des_0_9", 
             
            "y_CO2_ads_9_0",
             "y_CO2_ads_9_5",
             "y_CO2_ads_9_9",
             "y_CO2_des_0_0",
             "y_CO2_des_0_5",
             "y_CO2_des_0_9",
            "y_CO2_ads_9_1", 
             "y_CO2_ads_9_2",
             "y_CO2_ads_9_3",
             "y_CO2_ads_9_4",
             "y_CO2_ads_9_6",
             "y_CO2_ads_9_7",
             "y_CO2_ads_9_8", 
             #"y_CO2_des_0_1", 
             #"y_CO2_des_0_2",
             #"y_CO2_des_0_3",
             #"y_CO2_des_0_4",
             #"y_CO2_des_0_6",
             #"y_CO2_des_0_7",
             #"y_CO2_des_0_8", 
             
             
            "Tg_ads_9_0", 
            "Tg_ads_9_5", 
            "Tg_ads_9_9", 
            "Tg_des_0_0", 
            "Tg_des_0_5", 
            "Tg_des_0_9", 
            ]  


compute_trace_from_idx(benchmark)
# Out:
# 338966985.0127491
# [[ 6.60174604e+01  1.37862950e+02 -2.95673748e+04  1.15586570e+03
#   -2.16367401e-01]
#  [ 1.37862950e+02  4.22018787e+03 -7.99216510e+05  2.04945504e+04
#   -8.03523980e+00]
#  [-2.95673748e+04 -7.99216510e+05  3.38700690e+08 -8.58551533e+06
#    1.27565412e+03]
#  [ 1.15586570e+03  2.04945504e+04 -8.58551533e+06  2.62008742e+05
#   -3.56821587e+01]
#  [-2.16367401e-01 -8.03523980e+00  1.27565412e+03 -3.56821587e+01
#    2.23387307e-02]]
# trace: 338966985.0127491
# det: 1.3099725170871796e+16
# log10 trace: 8.530157400489149
# log10 det: 16.11726218435608

# %%
sol_1500 = [#"vg_des_0_3", 
            #"vg_des_0_7",
            #"vg_des_0_2",
           
           # "y_CO2_des_0_5",
           #"y_CO2_des_0_6",
           #"y_CO2_des_0_7",
           #"y_CO2_des_0_8",
           #"y_CO2_des_0_9",
            "y_CO2_ads_9_0",
            "y_CO2_ads_9_9",

           "y_CO2_des_0_1",
           "y_CO2_des_0_2",
           #"y_CO2_des_0_3",
           #"y_CO2_des_0_4",
           "y_CO2_des_0_0",
        #"y_CO2_des_1_1",
    
           #"y_CO2_des_7_9",
           # "y_CO2_des_8_9",
           # "y_CO2_des_9_9", 
            
            #"Tg_des_9_6", 
            #"Tg_des_9_7",
            #"Tg_des_2_7", 
            #"Tg_des_2_6",
    
            "Tg_des_0_8",
            "Tg_des_0_9",
           "Tg_des_0_7",
            #"Tg_des_0_5",
            #"Tg_des_0_6",
            
           ]
compute_trace_from_idx(sol_1500)
# Out:
# 291911382.5923861
# [[ 4.10334759e+00  9.89260858e+01 -3.15968861e+03 -2.81557239e+01
#   -2.61061257e-01]
#  [ 9.89260858e+01  3.47230252e+03 -3.64963870e+05  4.41183654e+03
#   -6.67855800e+00]
#  [-3.15968861e+03 -3.64963870e+05  2.91787166e+08 -5.83682471e+06
#   -8.81458627e+01]
#  [-2.81557239e+01  4.41183654e+03 -5.83682471e+06  1.20740072e+05
#    8.28688009e+00]
#  [-2.61061257e-01 -6.67855800e+00 -8.81458627e+01  8.28688009e+00
#    1.90060185e-02]]
# trace: 291911382.59238607
# det: 1775459851745.5903

# %%
def create_initial(idx_sol):
    
    init = np.zeros((num_total_measure, num_total_measure))
    
    for i in idx_sol:
        init[i,i] = 1 
        
    for i in range(num_total_measure):
        for j in range(num_total_measure):
            if init[i,i]==1 and init[j,j]==1:
                init[i,j] = 1 
                init[j,i] = 1 
    
    return init

sol = create_initial(names_idx)

# %%
def save_pickle(data, name): 
    file = open(name, "wb")
    pickle.dump(data, file)
    file.close()
    
save_pickle(total_fim, "MILP_fim_8000")
